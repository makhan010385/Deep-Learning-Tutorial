# %% [markdown]
# #implementaion Of CNN model

# %% [markdown]
# #1. importing the required libraries

# %%
#importing the required libraries
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPool2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense

# %% [markdown]
# #2. loading data

# %%
(X_train,y_train) , (X_test,y_test)=mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step

# %% [markdown]
# #3. reshaping data

# %%
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], X_train.shape[2], 1))
X_test = X_test.reshape((X_test.shape[0],X_test.shape[1],X_test.shape[2],1))

# %% [markdown]
# #4.checking the shape after reshaping

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)

# %% [markdown]
# #5. normalizing the pixel values

# %%
X_train=X_train/255
X_test=X_test/255

# %% [markdown]
# #6. defining model

# %%
model=Sequential()

# %% [markdown]
# #7. adding convolution layer

# %%
model.add(Conv2D(32,(3,3),activation='relu',input_shape=(28,28,1)))

# %% [markdown]
# #8. adding pooling layer

# %%
model.add(MaxPool2D(2,2))

# %% [markdown]
# #9. adding fully connected layer

# %%
model.add(Flatten())
model.add(Dense(100,activation='relu'))

# %% [markdown]
# #10. adding output layer

# %%
model.add(Dense(10,activation='softmax'))

# %% [markdown]
# #11. compiling the model

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %% [markdown]
# #12. fitting the model

# %%
model.fit(X_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 39s 20ms/step - loss: 0.1486 - accuracy: 0.9557
# Epoch 2/10
# 1875/1875 [==============================] - 38s 20ms/step - loss: 0.0525 - accuracy: 0.9839
# Epoch 3/10
# 1875/1875 [==============================] - 38s 20ms/step - loss: 0.0348 - accuracy: 0.9893
# Epoch 4/10
# 1875/1875 [==============================] - 38s 20ms/step - loss: 0.0238 - accuracy: 0.9923
# Epoch 5/10
# 1875/1875 [==============================] - 39s 21ms/step - loss: 0.0159 - accuracy: 0.9948
# Epoch 6/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0114 - accuracy: 0.9964
# Epoch 7/10
# 1875/1875 [==============================] - 38s 20ms/step - loss: 0.0080 - accuracy: 0.9973
# Epoch 8/10
# 1875/1875 [==============================] - 38s 20ms/step - loss: 0.0071 - accuracy: 0.9975
# Epoch 9/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0054 - accuracy: 0.9983
# Epoch 10/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0052 - accuracy: 0.9983

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 32)        0
#  D)
#
#  flatten (Flatten)           (None, 5408)              0
#
#  dense (Dense)               (None, 100)               540900
#
#  dense_1 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 542230 (2.07 MB)
# Trainable params: 542230 (2.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ![Deep.png](data:image/png;base64,...)

# %% [markdown]
# #13. evaluting the model

# %% [markdown]
# model.evaluate(X_test,y_test)

# %% [markdown]
# ![Eva.png](data:image/png;base64,...)

# %% [markdown]
# Q.1
#  loss function  ="categorical_crossentropy"
#
#  optimizer     ="stocastic gradient descent (sgd)"
#
#  metric  =  "accuracy"
